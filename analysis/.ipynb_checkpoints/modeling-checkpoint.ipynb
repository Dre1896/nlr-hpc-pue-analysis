# %%
import sklearn as sk
import pandas as pd
import numpy as np

import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

pue_hourly = pd.read_parquet('pue_hourly_cleaned.parquet')
pue_hourly.head()

# %% [markdown]
# # Preamble
#
# I'll be implementing a number of different methods. This will include but isn't limited to:
#
# - Autocorrelation plot on PUE to justify LSTM over a simpler model
# - ACF/PACF plots to determine lag window for the LSTM
# - Feature Engineering lag features and rolling statistics (rolling 24-hour mean, first differences, hour of day, day of week, extracted from timestamps)
# -

# %%
from pandas.plotting import autocorrelation_plot
from statsmodels.graphis.tsaplots import plot_acf, plot_pacf

autocorrelation_plot(pue_hourly['pue'])

plot_acf(pue_hourly['pue'], lags=48) # 2 day window span to ID if patterns exist or not
plot_pacf(pue_hourly['pue'], lags=48) # What lag order does PACF suggest
